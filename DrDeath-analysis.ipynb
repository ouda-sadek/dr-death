# %% [markdown]
# # Dr Death - Analyse des données
#
# -----
#
# Ce projet vise à analyser les données liées aux crimes du Dr Harold Shipman, l’un des **tueurs en série les plus prolifiques de l’histoire moderne**. Médecin généraliste dans le Grand Manchester, il a été reconnu coupable d’avoir assassiné plus de **200 patients** entre 1975 et 1998.
#
# ------
#
#
# ## Objectif de l’étude
#
# L’objectif est de :
#
# - Identifier les **profils types** des victimes (âge, sexe, lieu, période)
# - Mettre en évidence des **anomalies temporelles** (heures de décès anormales)
# - Comprendre si **des signaux statistiques** auraient pu permettre de le détecter plus tôt
# - Réaliser une **analyse exploratoire de données (EDA)** avec des visualisations claires
#
# Ce travail s’inscrit dans une approche de **data science appliquée à la criminalistique**, en utilisant Python et des outils de visualisation pour révéler des motifs cachés dans des données réelles.
#
# ---
#
# ## Données utilisées
#
# Deux fichiers CSV sont analysés :
# - `shipman-confirmed-victims.csv` : liste des victimes confirmées (âge, sexe, date, lieu, etc.)
# - `shipman-times-comparison.csv` : heures de décès chez Shipman vs autres médecins
#
# ---
#
# ## Outils
#
# - **Python** (Pandas, Matplotlib, Seaborn)
# - **Jupyter Notebook**
# - Méthodologie de data analysis : importation, nettoyage, visualisation, interprétation
#
# ------

# %%
# Importation des bibliothèques
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Pour afficher les graphiques directement dans le notebook
# %matplotlib inline

# Chargement des données
df = pd.read_csv('shipman-confirmed-victims.csv')  # fichier des victimes de Shipman

# Affichage des premières lignes du jeu de données
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#      10 # Chargement des données
# ---> 11 df = pd.read_csv('shipman-confirmed-victims.csv')  # fichier des victimes de Shipman
#      13 # Affichage des premières lignes du jeu de données
#      14 df.head()
#
# ...
